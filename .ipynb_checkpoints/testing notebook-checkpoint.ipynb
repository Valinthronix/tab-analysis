# %%
import tabula

# %%
stevenson = tabula.read_pdf("C:\\Users\\jmeye\\Documents\\4 - Stevenson Regional Tab Summary 2018.pdf", pages=[1,2], lattice=True)

# %%
stevenson
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Team</th>
#       <th>Round 1</th>
#       <th>Round 2</th>
#       <th>Round 3</th>
#       <th>Round 4</th>
#       <th>Summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1009\rUniversity of Maryland, College\rPark</td>
#       <td>?v.1551\rLL\r-5-6</td>
#       <td>?v.1220\rLL\r-8-8</td>
#       <td>?v.1346\rWW\r+16+21</td>
#       <td>?v.1644\rWW\r+8+28</td>
#       <td>4-4-0\rCSOCSPD\r1666+46</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1012\rUniversity of Maryland, College\rPark</td>
#       <td>?v.1346\rWW\r+9+1</td>
# ...
